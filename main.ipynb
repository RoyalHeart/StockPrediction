# %%
# %run "./modules/model.py"
# Out:
# Number of GPUs Available:  1

# %%
stock_model = StockPrediction(
        StockCode.VIC,
    )
stock_model.train(
    start_date=datetime.datetime(2021, 1, 1),
    model_type=ModelType.LSTM_DNN,
    epoch_size=200,
    batch_size=2,
    time_step=4,
    ratio=0.8,
)
# Out:
# 524 131
# Model: "sequential_4"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  lstm_3 (LSTM)               (None, 4, 50)             10400
#
#  dropout (Dropout)           (None, 4, 50)             0
#
#  lstm_4 (LSTM)               (None, 4, 50)             20200
#
#  lstm_5 (LSTM)               (None, 50)                20200
#
#  dense_4 (Dense)             (None, 16)                816
#
#  dense_5 (Dense)             (None, 8)                 136
#
#  dense_6 (Dense)             (None, 1)                 9
#
# =================================================================
# Total params: 51,761
# Trainable params: 51,761
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/200
# 259/259 - 8s - loss: 0.0124 - 8s/epoch - 29ms/step
# Epoch 2/200
# 259/259 - 3s - loss: 0.0045 - 3s/epoch - 10ms/step
# Epoch 3/200
# 259/259 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 4/200
# 259/259 - 3s - loss: 0.0041 - 3s/epoch - 10ms/step
# Epoch 5/200
# 259/259 - 3s - loss: 0.0037 - 3s/epoch - 10ms/step
# Epoch 6/200
# 259/259 - 3s - loss: 0.0036 - 3s/epoch - 10ms/step
# Epoch 7/200
# 259/259 - 3s - loss: 0.0037 - 3s/epoch - 10ms/step
# Epoch 8/200
# 259/259 - 3s - loss: 0.0037 - 3s/epoch - 10ms/step
# Epoch 9/200
# 259/259 - 3s - loss: 0.0042 - 3s/epoch - 11ms/step
# Epoch 10/200
# 259/259 - 3s - loss: 0.0034 - 3s/epoch - 11ms/step
# Epoch 11/200
# 259/259 - 3s - loss: 0.0033 - 3s/epoch - 11ms/step
# Epoch 12/200
# 259/259 - 3s - loss: 0.0039 - 3s/epoch - 11ms/step
# Epoch 13/200
# 259/259 - 3s - loss: 0.0041 - 3s/epoch - 11ms/step
# Epoch 14/200
# 259/259 - 3s - loss: 0.0033 - 3s/epoch - 10ms/step
# Epoch 15/200
# 259/259 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 16/200
# 259/259 - 3s - loss: 0.0030 - 3s/epoch - 10ms/step
# Epoch 17/200
# 259/259 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 18/200
# 259/259 - 3s - loss: 0.0035 - 3s/epoch - 10ms/step
# Epoch 19/200
# 259/259 - 3s - loss: 0.0031 - 3s/epoch - 11ms/step
# Epoch 20/200
# 259/259 - 3s - loss: 0.0032 - 3s/epoch - 10ms/step
# Epoch 21/200
# 259/259 - 3s - loss: 0.0030 - 3s/epoch - 10ms/step
# Epoch 22/200
# 259/259 - 3s - loss: 0.0032 - 3s/epoch - 10ms/step
# Epoch 23/200
# 259/259 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 24/200
# 259/259 - 3s - loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 25/200
# 259/259 - 3s - loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 26/200
# 259/259 - 2s - loss: 0.0029 - 2s/epoch - 10ms/step
# Epoch 27/200
# 259/259 - 3s - loss: 0.0029 - 3s/epoch - 10ms/step
# Epoch 28/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 10ms/step
# Epoch 29/200
# 259/259 - 3s - loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 30/200
# 259/259 - 3s - loss: 0.0028 - 3s/epoch - 10ms/step
# Epoch 31/200
# 259/259 - 3s - loss: 0.0030 - 3s/epoch - 11ms/step
# Epoch 32/200
# 259/259 - 3s - loss: 0.0027 - 3s/epoch - 10ms/step
# Epoch 33/200
# 259/259 - 3s - loss: 0.0029 - 3s/epoch - 10ms/step
# Epoch 34/200
# 259/259 - 3s - loss: 0.0028 - 3s/epoch - 10ms/step
# Epoch 35/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 36/200
# 259/259 - 3s - loss: 0.0028 - 3s/epoch - 10ms/step
# Epoch 37/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 11ms/step
# Epoch 38/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 11ms/step
# Epoch 39/200
# 259/259 - 3s - loss: 0.0029 - 3s/epoch - 10ms/step
# Epoch 40/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 41/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 42/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 43/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 10ms/step
# Epoch 44/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 45/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 11ms/step
# Epoch 46/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 10ms/step
# Epoch 47/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 48/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 11ms/step
# Epoch 49/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 11ms/step
# Epoch 50/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 11ms/step
# Epoch 51/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 11ms/step
# Epoch 52/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 53/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 54/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 11ms/step
# Epoch 55/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 56/200
# 259/259 - 3s - loss: 0.0026 - 3s/epoch - 10ms/step
# Epoch 57/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 58/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 59/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 60/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 61/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 11ms/step
# Epoch 62/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 63/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 64/200
# 259/259 - 2s - loss: 0.0023 - 2s/epoch - 10ms/step
# Epoch 65/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 66/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 67/200
# 259/259 - 2s - loss: 0.0022 - 2s/epoch - 10ms/step
# Epoch 68/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 69/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 70/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 71/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 72/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 73/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 74/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 75/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 11ms/step
# Epoch 76/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 11ms/step
# Epoch 77/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 78/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 11ms/step
# Epoch 79/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 80/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 81/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 82/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 83/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 84/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 85/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 86/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 87/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 88/200
# 259/259 - 3s - loss: 0.0024 - 3s/epoch - 10ms/step
# Epoch 89/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 90/200
# 259/259 - 3s - loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 91/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 92/200
# 259/259 - 3s - loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 93/200
# 259/259 - 3s - loss: 0.0025 - 3s/epoch - 10ms/step
# Epoch 94/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 95/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 96/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 97/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 98/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 99/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 100/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 101/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 102/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 103/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 104/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 105/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 106/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 107/200
# 259/259 - 3s - loss: 0.0020 - 3s/epoch - 11ms/step
# Epoch 108/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 109/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 11ms/step
# Epoch 110/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 11ms/step
# Epoch 111/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 11ms/step
# Epoch 112/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 113/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 114/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 115/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 116/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 117/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 118/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 119/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 120/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 121/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 122/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 123/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 124/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 125/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 126/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 127/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 128/200
# 259/259 - 3s - loss: 0.0023 - 3s/epoch - 10ms/step
# Epoch 129/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 130/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 131/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 132/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 133/200
# 259/259 - 3s - loss: 0.0020 - 3s/epoch - 10ms/step
# Epoch 134/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 135/200
# 259/259 - 3s - loss: 0.0021 - 3s/epoch - 10ms/step
# Epoch 136/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 10ms/step
# Epoch 137/200
# 259/259 - 3s - loss: 0.0022 - 3s/epoch - 11ms/step
# WARNING:absl:Found untraced functions such as lstm_cell_3_layer_call_fn, lstm_cell_3_layer_call_and_return_conditional_losses, lstm_cell_4_layer_call_fn, lstm_cell_4_layer_call_and_return_conditional_losses, lstm_cell_5_layer_call_fn while saving (showing 5 of 6). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./StockPredict/VIC/23\assets
# INFO:tensorflow:Assets written to: ./StockPredict/VIC/23\assets
# 17/17 [==============================] - 1s 6ms/step
# 4/4 [==============================] - 0s 5ms/step
# Train MAE Score: 2.2512917519 MAE
# Test MAE Score: 2.4568417072 MAE
# Train MAPE Score: 0.0270 MAPE
# Test MAPE Score: 0.0448 MAPE
# Train Score: 3.2990 RMSE
# Test Score: 2.8037 RMSE
# Train RMSPE: 0.0383 RMSPE
# Test RMSPE: 0.0492 RMSPE

# %%
dataset = stock_model.get_dataset()
# dataset = stock_model.transform(dataset)
stock_model.plot_result(dataset)
